# %% [markdown]
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN">
# <html>
# <head>
# 	<meta http-equiv="content-type" content="text/html; charset=utf-8"/>
# 	<title></title>
# 	<meta name="generator" content="LibreOffice 6.4.7.2 (Linux)"/>
# 	<meta name="created" content="2022-01-23T00:50:45.359427357"/>
# 	<meta name="changed" content="2022-01-23T01:41:49.622757505"/>
# </head>
# <body lang="en-US" dir="ltr"><p><br/>
# <br/>
#
# </p>
# <p align="left"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><b><span style="font-variant: normal"><font color="#202122"><span style="letter-spacing: normal"><span style="font-style: normal">WeRateDogs:
# Adding the woof to your tweets ..</span></span></font></span></b></font></font></p>
# <p align="left"><font face="FreeSans, sans-serif"><font size="1" style="font-size: 8pt"><b><span style="font-variant: normal"><font color="#202122"><span style="letter-spacing: normal"><span style="font-style: normal">Blog
# Post By: Basel</span></span></font></span></b></font></font></p>
# <p><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="font-variant: normal"><font color="#202122"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">Andrew
# McAfee once said : ‘The world is one big data problem’, and with
# the amount of data being generated daily nowadays, McAfee’s
# statement continues to echo day after day.</span></span></span></font></span></font></font></p>
# <p align="left"><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">Analyzing
# a</span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">
# data set </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">of
# </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">5000+
# tweets as they stood </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">as
# of</span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">
# August 1, 2017 </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#0f1419"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">for
# </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#202122"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">WeRateDogs,
# a </span></span></span></font></font></font></span><a href="https://en.wikipedia.org/wiki/Twitter"><span style="font-variant: normal"><font color="#0645ad"><span style="text-decoration: none"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal"><span style="background: #ffffff">Twitter</span></span></span></span></font></font></span></font></span></a><span style="font-variant: normal"><font color="#202122"><span style="text-decoration: none"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal"><span style="background: #ffffff">
# </span></span></span></span></font></font></span></font></span><span style="font-variant: normal"><font color="#202122"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">account
# that rates people's </span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#202122"><span style="text-decoration: none"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal"><span style="background: #ffffff">dogs
# </span></span></span></span></font></font></span></font></span><span style="font-variant: normal"><font color="#202122"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">with
#  humorous comment</span></span></span></font></font></font></span><span style="font-variant: normal"><font color="#202122"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">s
# has revealed the a shift in the way we use technology with WeRateDogs
# tweeting 93.8% of the time through the smart phone instead of a
# computer.</span></span></span></font></font></font></span></p>
# <p align="left"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="font-variant: normal"><font color="#202122"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">The
# analysis also revealed that over 36% of the tweets for the
# WeRateDogs account were between 00:00 and 2:59 with the rest of the
# tweets spread along the remaining hours and a short period of no
# tweeting as observed in the below histogram.</span></span></span></font></span></font></font></p>
# <p align="left"><br/>
# <br/>
#
# </p>
# <p align="left"><img src="histplt.png" name="Image5" align="left" width="1198" height="299">
#   <br clear="left"/>
# </img>
# <br/>
# <br/>
#
# </p>
# <p style="margin-bottom: 0.09in; font-variant: normal; letter-spacing: normal; font-style: normal; font-weight: normal; orphans: 2; widows: 2">
# <font color="#000000"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt">It
# was also observed that the number of retweets and the number of
# favorite tweets show a linear relationship.</font></font></font></p>
# <p style="margin-bottom: 0.09in; font-variant: normal; letter-spacing: normal; font-style: normal; font-weight: normal; orphans: 2; widows: 2">
# <img src="scatterplot.png" name="Image6" align="left" width="846" height="444">
#   <br clear="left"/>
# </img>
# <br/>
# <br/>
#
# </p>
# <p style="margin-bottom: 0.09in; font-variant: normal; letter-spacing: normal; font-style: normal; font-weight: normal; orphans: 2; widows: 2">
# <font color="#000000"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt">This
# relationship was further investigated to assess the effect of the dog
# rating and it was concluded that the dogs obtaining a 13/10 rating
# are the most likely to be retweeted and favorited, as shown in the
# below heat map</font></font></font></p>
# <p style="margin-bottom: 0.09in; font-variant: normal; letter-spacing: normal; font-style: normal; font-weight: normal; orphans: 2; widows: 2">
# <img src="heatmap.png" name="Image7" align="left" width="907" height="491">
#   <br clear="left"/>
# </img>
# <br/>
# <br/>
#
# </p>
# <p style="margin-bottom: 0.09in; font-variant: normal; letter-spacing: normal; font-style: normal; font-weight: normal; orphans: 2; widows: 2">
# <font color="#000000"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt">Further
# analysis of the data revealed that the Golden Retriever is the most
# submitted dog breed to rate, and that the dog names 'Charlie','Lucy',
# 'Oliver' and 'Cooper are the most popular with 65% of the total
# sample classified as a pupper on the dogtionary rating</font></font></font></p>
# <p style="margin-bottom: 0.09in; orphans: 2; widows: 2"><br/>
# <br/>
#
# </p>
# <p><br/>
# <br/>
#
# </p>
# <p><img src="wordcloud.png" name="Image3" align="left" width="877" height="602">
#   <br clear="left"/>
# </img>
# <br/>
# <br/>
#
# </p>
# <p align="left"><font face="FreeSans, sans-serif"><font size="4" style="font-size: 15pt"><span style="font-variant: normal"><font color="#202122"><span style="letter-spacing: normal"><span style="font-style: normal"><span style="font-weight: normal">WeRateDogs
# continues to grow in popularity as it had over 4 MM followers at the
# time the data was collected  and has grown to over 9.1 MM at the time
# this report was created. The current data set is 3 folds the analyzed
# data 5K+ vs. ~15K which would warrant a rerun of this analysis to
# explore the changes in trend over time and further investigate the
# drivers for the popularity of the account that continues to woof ..</span></span></span></font></span></font></font></p>
# <p align="left"><br/>
# <br/>
#
# </p>
# </body>
# </html>
